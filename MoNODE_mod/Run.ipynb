# %%
import os 
import argparse, time
import numpy as np
import torch
from datetime import datetime
from model.build_model import build_model
from model.model_misc import train_model 
from model.misc import io_utils
from model.misc.torch_utils import seed_everything, count_params
from data.data_utils import load_data

# %%
ar = argparse.Namespace(
        task='ais',
        noise=None,
        Nobj=1,
        num_workers=0,
        data_root='AIS/',
        shuffle=True,
        
        # setting for ODE model
        # set baseline model to latent node
        model='node',
        ode_latent_dim=6,
        # Num of hidden layers in MLP diff func
        de_L=2,
        # Num of hidden neurons in MLP diff func
        de_H=128,

        # modulator
        # Invariant function
        inv_fnc='MLP',
        # dim of dynamic modulator
        modulator_dim=0,
        # dim of static modulator
        content_dim=0,
        # Time frames to select for RNN based Encoder for Invariance
        T_inv=0,
        # Nfilt invariant encoder cnn
        cnn_filt_inv = 16,

        # ode solver setting
        order = 1,
        solver = 'euler',
        dt = 0.1,
        use_adjoint = 'no_adjoint',

        # VAE (encoder decoder part)
        T_in = 50,
        cnn_filt_enc = 16,
        cnn_filt_de = 16,
        rnn_hidden = 10,
        dec_H = 128,
        dec_L = 2,
        dec_act = 'relu',
        enc_H = 50,

        # training setting
        Nepoch = 2000,
        # Number of sequential increments of the sequence length
        Nincr = 3,
        batch_size = 16,
        lr = 0.002,
        seed = 13,
        continue_training = False,
        plot_every = 250,
        plotL = 1,
        # num of forecast steps for plotting
        forecast_tr = 2,
        forecast_vl = 2,
        exp_id = 100,

        # save
        save = 'results/',
    )

# %%
def perform(args):
    ######### setup output directory and logger ###########
    args.save = os.path.join(os.getcwd(), \
        args.save+args.task+'/'+args.model+'/'+str(args.exp_id), '')

    ############################
    io_utils.makedirs(args.save)
    io_utils.makedirs(os.path.join(args.save, 'plots'))
    io_utils.makedirs(os.path.join(args.save, 'plots', 'fit'))
    io_utils.makedirs(os.path.join(args.save, 'plots', 'latents'))
    logger = io_utils.get_logger(logpath=os.path.join(args.save, 'logs.txt'))
    logger.info('Results stored in {}'.format(args.save))

    ########## set global random seed ###########
    if args.seed==-1:
        args.seed = int(time.time()*np.random.random()/1000)
    seed_everything(args.seed)

    ########## dtype #########
    dtype = torch.float64
    logger.info('********** Float type is {} ********** '.format(dtype))

    ########## plotter #######
    from model.misc.plot_utils import Plotter
    save_path = os.path.join(args.save, 'plots')
    plotter   = Plotter(save_path, args.task)

    ########### device #######
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    logger.info('********** Running model on {} ********** '.format(device))

    ########### data ############
    trainset, validset, testset, params = load_data(args, device, dtype)
    logger.info('********** {} dataset with loaded ********** '.format(args.task))
    logger.info('data params: {}'.format(params[args.task]))

    ########### model ###########
    model = build_model(args, device, dtype)
    model.to(device)
    model.to(dtype)

    logger.info('********** Built {} model with dynamics modulator dim {} and  content variable dim {}**********'.format(args.model, args.modulator_dim, args.content_dim))
    logger.info('********** Number of parameters: {} **********'.format(count_params(model)))
    logger.info('********** Augmented Dynamics: {} **********'.format(model.aug))
    for arg, value in sorted(vars(args).items()):
        logger.info("Argument %s: %r", arg, value)
    logger.info(model)

    if args.continue_training:
        fname = os.path.join(os.path.abspath(os.path.dirname(__file__)), args.save, 'model.pth')
        model.load_state_dict(torch.load(fname,map_location=torch.device(device)))
        logger.info('********** Resume training for model {} ********** '.format(fname))

    train_model(args, model, plotter, trainset, validset, testset, logger, params[args.task])

# %%
def buildArgs(t_in, t_inv, ode_latent_dim, dynamic_dim, static_dim, exp_id):
    args = argparse.Namespace(
        task='ais',
        noise=None,
        Nobj=1,
        num_workers=0,
        data_root='AIS/',
        shuffle=True,
        
        # setting for ODE model
        # set baseline model to latent node
        model='node',
        ode_latent_dim=ode_latent_dim,
        # Num of hidden layers in MLP diff func
        de_L=2,
        # Num of hidden neurons in MLP diff func
        de_H=128,

        # modulator
        # Invariant function
        inv_fnc='MLP',
        # dim of dynamic modulator
        modulator_dim=dynamic_dim,
        # dim of static modulator
        content_dim=static_dim,
        # Time frames to select for RNN based Encoder for Invariance
        T_inv=t_inv,
        # Nfilt invariant encoder cnn
        cnn_filt_inv = 16,

        # ode solver setting
        order = 1,
        solver = 'euler',
        dt = 0.1,
        use_adjoint = 'no_adjoint',

        # VAE (encoder decoder part)
        T_in = t_in,
        cnn_filt_enc = 16,
        cnn_filt_de = 16,
        rnn_hidden = 10,
        dec_H = 128,
        dec_L = 2,
        dec_act = 'relu',
        enc_H = 50,

        # training setting
        Nepoch = 2000,
        # Number of sequential increments of the sequence length
        Nincr = 3,
        batch_size = 16,
        lr = 0.002,
        seed = 13,
        continue_training = False,
        plot_every = 250,
        plotL = 1,
        # num of forecast steps for plotting
        forecast_tr = 2,
        forecast_vl = 2,
        exp_id = exp_id,

        # save
        save = 'results/',
    )

    perform(args)

# %%
def match(setting):
    buildArgs(setting[0], setting[1], setting[2], setting[3], setting[4], setting[5])

# %%
# experiment model explanation: exp_id (can be found from results/ais/node)
settings = [
    # NODE with dim 6: 0
    [50, 0, 6, 0, 0, 0],
    # NODE with dim 12: 1
    [50, 0, 12, 0, 0, 1],
    # NODE with dim 24: 2
    [50, 0, 24, 0, 0, 2],
    # MoNODE with static modulator and dim 3: 10
    [50, 50, 3, 0, 3, 10],
    # MoNODE with static modulator and dim 6: 11
    [50, 50, 6, 0, 6, 11],
    # MoNODE with static modulator and dim 12: 12
    [50, 50, 12, 0, 12, 12],
    # MoNODE with dynamic modulator and dim 3: 20
    [50, 50, 3, 3, 0, 20],
    # MoNODE with dynamic modulator and dim 6: 21
    [50, 50, 3, 3, 0, 21],
    # MoNODE with dynamic modulator and dim 12: 22
    [50, 50, 3, 3, 0, 22],
    # MoNODE with both modulator and dim 2: 30
    [50, 50, 2, 2, 2, 30],
    # MoNODE with both modulator and dim 4: 30
    [50, 50, 4, 4, 4, 31],
    # MoNODE with both modulator and dim 8: 30
    [50, 50, 8, 8, 8, 32],
]

# %%
from multiprocessing import *

pool = Pool(processes=12)
pool.map(func=match, iterable=settings)
# Out:
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/2/
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/10/
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/0/
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/21/
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/22/
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/20/
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/1/
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/11/
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/12/
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/30/
# ********** Float type is torch.float64 **********
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/32/
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/31/
# ********** Float type is torch.float64 **********
# ********** Float type is torch.float64 **********
# ********** Float type is torch.float64 **********
# ********** Float type is torch.float64 **********
# ********** Float type is torch.float64 **********
# ********** Float type is torch.float64 **********
# ********** Float type is torch.float64 **********
# ********** Float type is torch.float64 **********
# ********** Float type is torch.float64 **********
# ********** Running model on cuda **********
# ********** Running model on cuda **********
# ********** Float type is torch.float64 **********
# ********** Float type is torch.float64 **********
# ********** Running model on cuda **********
# ********** Running model on cuda **********
# ais
# ********** Running model on cuda **********
# ********** Running model on cuda **********
# aisais
#
# TrueTrue
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# ********** Running model on cuda **********
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']ais
# ais
# ********** Running model on cuda **********
# ********** Running model on cuda **********
# ********** Running model on cuda **********
# ********** Running model on cuda **********
# ais
# aisaisaisais
#
#
# True
# aisTrueTrue
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# ********** Running model on cuda **********
# True
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# True
#
# ais
# TrueTrue
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# True
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# True
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# True
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
#
#
#
#
#
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
#
#
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:89: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:90: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:89: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:90: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
#
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:91: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:89: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:90: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:89: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:90: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# ...
# Epoch:1991/2000 | tr_loss:494209.28(420228.27) | valid_mse T=50 :4015.282 | valid_mse T=100 :6775.507
# Epoch:1984/2000 | tr_loss:396439.56(405542.93) | valid_mse T=50 :8176.297 | valid_mse T=100 :7776.637
# Epoch:1987/2000 | tr_loss:246373.67(427874.87) | valid_mse T=50 :8527.773 | valid_mse T=100 :7660.984
# Epoch:1992/2000 | tr_loss:426125.44(395760.87) | valid_mse T=50 :4016.620 | valid_mse T=100 :6373.894
# Epoch:1984/2000 | tr_loss:468050.48(435840.23) | valid_mse T=50 :8375.633 | valid_mse T=100 :8803.784
# Epoch:1980/2000 | tr_loss:476507.25(443061.54) | valid_mse T=50 :6318.999 | valid_mse T=100 :6692.633
# Epoch:1990/2000 | tr_loss:389345.19(408166.61) | valid_mse T=50 :6436.014 | valid_mse T=100 :6711.298
# Epoch:1990/2000 | tr_loss:426154.32(391275.85) | valid_mse T=50 :8590.173 | valid_mse T=100 :7409.423
# Epoch:1985/2000 | tr_loss:372083.92(404539.16) | valid_mse T=50 :8516.483 | valid_mse T=100 :7615.167
# Epoch:1992/2000 | tr_loss:424481.82(420355.88) | valid_mse T=50 :4033.532 | valid_mse T=100 :6901.598
# Epoch:1988/2000 | tr_loss:459145.60(428812.99) | valid_mse T=50 :8548.986 | valid_mse T=100 :8711.789
# Epoch:1998/2000 | tr_loss:796543.50(401044.53) | valid_mse T=50 :6965.462 | valid_mse T=100 :7443.214
# Epoch:1993/2000 | tr_loss:432572.68(396865.23) | valid_mse T=50 :3970.269 | valid_mse T=100 :6340.452
# Epoch:1985/2000 | tr_loss:496286.86(437653.63) | valid_mse T=50 :8521.421 | valid_mse T=100 :7371.706
# Epoch:1981/2000 | tr_loss:487021.27(444380.33) | valid_mse T=50 :6727.877 | valid_mse T=100 :6725.815
# Epoch:1991/2000 | tr_loss:456471.56(409615.76) | valid_mse T=50 :6582.051 | valid_mse T=100 :7114.622
# Epoch:1991/2000 | tr_loss:314397.03(388969.49) | valid_mse T=50 :7914.425 | valid_mse T=100 :7437.360
# Epoch:1993/2000 | tr_loss:386729.27(419347.08) | valid_mse T=50 :4100.474 | valid_mse T=100 :6989.379
# Epoch:1986/2000 | tr_loss:219482.58(398987.46) | valid_mse T=50 :8032.002 | valid_mse T=100 :7733.147
# Epoch:1989/2000 | tr_loss:462039.35(429809.78) | valid_mse T=50 :7680.447 | valid_mse T=100 :7442.178
# Epoch:1994/2000 | tr_loss:422418.18(397631.82) | valid_mse T=50 :3998.481 | valid_mse T=100 :6379.994
# Epoch:1999/2000 | tr_loss:822440.59(413686.41) | valid_mse T=50 :7200.192 | valid_mse T=100 :7192.322
# Epoch:1999/2000 | time: 2:38:23.752707 | train_elbo: 822440.59 | train_mse: 783.270 | valid_mse_rec: 7200.192) | valid_mse_for: 7192.322)  | best_valid_mse: 4832.566)
# T=50 test_mse 423.428(0.000)
# T=100 test_mse 2195.699(0.000)
# Epoch:1986/2000 | tr_loss:298809.48(433488.31) | valid_mse T=50 :7901.313 | valid_mse T=100 :6460.578
# Epoch:1982/2000 | tr_loss:436400.22(444140.93) | valid_mse T=50 :6713.716 | valid_mse T=100 :6844.835
# Epoch:1992/2000 | tr_loss:336613.62(407425.69) | valid_mse T=50 :5684.232 | valid_mse T=100 :6239.099
# Epoch:1994/2000 | tr_loss:460981.94(420596.13) | valid_mse T=50 :4078.460 | valid_mse T=100 :7038.548
# Epoch:1990/2000 | tr_loss:440946.26(430143.88) | valid_mse T=50 :8125.670 | valid_mse T=100 :8042.872
# Epoch:1992/2000 | tr_loss:324657.56(387040.13) | valid_mse T=50 :9207.172 | valid_mse T=100 :8040.504
# Epoch:1987/2000 | tr_loss:317158.34(396532.59) | valid_mse T=50 :7231.097 | valid_mse T=100 :7326.873
# Epoch:1995/2000 | tr_loss:390009.79(397403.16) | valid_mse T=50 :4045.294 | valid_mse T=100 :6431.828
# Epoch:1987/2000 | tr_loss:246373.67(427874.87) | valid_mse T=50 :8527.773 | valid_mse T=100 :7660.984
# Epoch:1983/2000 | tr_loss:445740.60(444188.92) | valid_mse T=50 :6799.502 | valid_mse T=100 :6889.582
# Epoch:1993/2000 | tr_loss:378793.19(406566.72) | valid_mse T=50 :6689.975 | valid_mse T=100 :6918.552
# Epoch:1995/2000 | tr_loss:378457.37(419331.97) | valid_mse T=50 :4027.141 | valid_mse T=100 :7022.869
# Epoch:1991/2000 | tr_loss:349035.44(427710.62) | valid_mse T=50 :8407.716 | valid_mse T=100 :7953.926
# Epoch:1993/2000 | tr_loss:461193.95(389264.74) | valid_mse T=50 :10626.193 | valid_mse T=100 :8876.123
# Epoch:1988/2000 | tr_loss:394989.38(396486.29) | valid_mse T=50 :7381.952 | valid_mse T=100 :7460.124
# Epoch:1996/2000 | tr_loss:295202.51(394337.14) | valid_mse T=50 :4066.362 | valid_mse T=100 :6465.238
# Epoch:1988/2000 | tr_loss:459145.60(428812.99) | valid_mse T=50 :8548.986 | valid_mse T=100 :8711.789
# Epoch:1984/2000 | tr_loss:406011.07(443043.58) | valid_mse T=50 :5884.980 | valid_mse T=100 :6483.668
# Epoch:1994/2000 | tr_loss:490012.04(409070.08) | valid_mse T=50 :5799.495 | valid_mse T=100 :6070.107
# Epoch:1996/2000 | tr_loss:400910.02(418779.31) | valid_mse T=50 :3862.500 | valid_mse T=100 :6929.944
# Epoch:1994/2000 | tr_loss:424168.81(390311.87) | valid_mse T=50 :9464.781 | valid_mse T=100 :7945.644
# Epoch:1992/2000 | tr_loss:378050.01(426220.80) | valid_mse T=50 :8702.907 | valid_mse T=100 :9806.742
# Epoch:1989/2000 | tr_loss:408856.76(396857.41) | valid_mse T=50 :8650.416 | valid_mse T=100 :8306.562
# Epoch:1997/2000 | tr_loss:290539.79(391223.22) | valid_mse T=50 :4134.365 | valid_mse T=100 :6518.617
# Epoch:1989/2000 | tr_loss:462039.35(429809.78) | valid_mse T=50 :7680.447 | valid_mse T=100 :7442.178
# Epoch:1985/2000 | tr_loss:438742.84(442914.56) | valid_mse T=50 :6154.093 | valid_mse T=100 :6742.295
# Epoch:1995/2000 | tr_loss:276229.88(405084.87) | valid_mse T=50 :6227.893 | valid_mse T=100 :6198.865
# Epoch:1997/2000 | tr_loss:397264.02(418133.85) | valid_mse T=50 :4001.467 | valid_mse T=100 :7064.807
# Epoch:1995/2000 | tr_loss:316103.06(388085.60) | valid_mse T=50 :9486.019 | valid_mse T=100 :8466.381
# Epoch:1993/2000 | tr_loss:518317.81(428983.71) | valid_mse T=50 :8333.227 | valid_mse T=100 :7904.077
# Epoch:1990/2000 | tr_loss:320590.11(394569.39) | valid_mse T=50 :6957.771 | valid_mse T=100 :7858.929
# Epoch:1998/2000 | tr_loss:389911.90(391183.88) | valid_mse T=50 :4128.936 | valid_mse T=100 :6484.167
# Epoch:1990/2000 | tr_loss:440946.26(430143.88) | valid_mse T=50 :8125.670 | valid_mse T=100 :8042.872
# Epoch:1986/2000 | tr_loss:486259.70(444214.91) | valid_mse T=50 :5675.595 | valid_mse T=100 :6507.579
# Epoch:1996/2000 | tr_loss:410167.78(405237.36) | valid_mse T=50 :6867.581 | valid_mse T=100 :6965.967
# Epoch:1996/2000 | tr_loss:271419.69(384585.62) | valid_mse T=50 :9202.714 | valid_mse T=100 :8171.666
# Epoch:1994/2000 | tr_loss:431010.68(429044.52) | valid_mse T=50 :8638.049 | valid_mse T=100 :8459.916
# Epoch:1991/2000 | tr_loss:281031.18(391163.24) | valid_mse T=50 :8681.898 | valid_mse T=100 :8581.395
# Epoch:1998/2000 | tr_loss:435169.42(418644.92) | valid_mse T=50 :3915.926 | valid_mse T=100 :7037.586
# Epoch:1991/2000 | tr_loss:349035.44(427710.62) | valid_mse T=50 :8407.716 | valid_mse T=100 :7953.926
# Epoch:1999/2000 | tr_loss:384002.44(390968.43) | valid_mse T=50 :4167.666 | valid_mse T=100 :6477.620
# Epoch:1999/2000 | time: 2:38:55.777529 | train_elbo: 384002.44 | train_mse: 802.907 | valid_mse_rec: 4167.666) | valid_mse_for: 6477.620)  | best_valid_mse: 2667.298)
# T=50 test_mse 59.061(0.000)
# T=100 test_mse 2252.469(0.000)
# Epoch:1987/2000 | tr_loss:447070.30(444300.58) | valid_mse T=50 :6356.946 | valid_mse T=100 :6709.758
# Epoch:1997/2000 | tr_loss:413656.80(405489.94) | valid_mse T=50 :6044.410 | valid_mse T=100 :6305.846
# Epoch:1997/2000 | tr_loss:297111.24(381961.39) | valid_mse T=50 :7768.602 | valid_mse T=100 :7060.013
# Epoch:1992/2000 | tr_loss:486502.01(394023.40) | valid_mse T=50 :7819.443 | valid_mse T=100 :7845.239
# Epoch:1995/2000 | tr_loss:401330.08(428213.09) | valid_mse T=50 :8327.987 | valid_mse T=100 :8655.629
# Epoch:1999/2000 | tr_loss:530434.13(421998.59) | valid_mse T=50 :4018.991 | valid_mse T=100 :7079.793
# Epoch:1999/2000 | time: 2:39:00.245634 | train_elbo: 530434.13 | train_mse: 851.518 | valid_mse_rec: 4018.991) | valid_mse_for: 7079.793)  | best_valid_mse: 2902.744)
# T=50 test_mse 78.052(0.000)
# T=100 test_mse 6127.605(0.000)
# Epoch:1992/2000 | tr_loss:378050.01(426220.80) | valid_mse T=50 :8702.907 | valid_mse T=100 :9806.742
# Epoch:1988/2000 | tr_loss:521868.88(446627.63) | valid_mse T=50 :6786.107 | valid_mse T=100 :7112.020
# Epoch:1998/2000 | tr_loss:777370.48(416646.36) | valid_mse T=50 :5077.624 | valid_mse T=100 :5820.846
# Epoch:1996/2000 | tr_loss:341823.72(425621.41) | valid_mse T=50 :8252.192 | valid_mse T=100 :7930.347
# Epoch:1993/2000 | tr_loss:350976.18(392731.99) | valid_mse T=50 :8182.204 | valid_mse T=100 :7707.504
# Epoch:1998/2000 | tr_loss:646044.51(389883.89) | valid_mse T=50 :8211.148 | valid_mse T=100 :7204.937
# Epoch:1993/2000 | tr_loss:518317.81(428983.71) | valid_mse T=50 :8333.227 | valid_mse T=100 :7904.077
# Epoch:1989/2000 | tr_loss:460959.13(447057.57) | valid_mse T=50 :7882.283 | valid_mse T=100 :7684.689
# Epoch:1994/2000 | tr_loss:273530.11(389155.93) | valid_mse T=50 :7482.929 | valid_mse T=100 :7952.405
# Epoch:1997/2000 | tr_loss:367144.70(423867.11) | valid_mse T=50 :8392.763 | valid_mse T=100 :8153.164
# Epoch:1999/2000 | tr_loss:439977.66(417346.30) | valid_mse T=50 :6931.372 | valid_mse T=100 :6846.830
# Epoch:1999/2000 | time: 2:39:08.205173 | train_elbo: 439977.66 | train_mse: 855.945 | valid_mse_rec: 6931.372) | valid_mse_for: 6846.830)  | best_valid_mse: 4039.625)
# T=50 test_mse 166.991(0.000)
# T=100 test_mse 1848.171(0.000)
# Epoch:1999/2000 | tr_loss:665199.71(398143.36) | valid_mse T=50 :9326.634 | valid_mse T=100 :7609.144
# Epoch:1999/2000 | time: 2:39:08.741944 | train_elbo: 665199.71 | train_mse: 774.039 | valid_mse_rec: 9326.634) | valid_mse_for: 7609.144)  | best_valid_mse: 4787.684)
# T=50 test_mse 91.171(0.000)
# T=100 test_mse 2044.821(0.000)
# Epoch:1994/2000 | tr_loss:431010.68(429044.52) | valid_mse T=50 :8638.049 | valid_mse T=100 :8459.916
# Epoch:1990/2000 | tr_loss:498256.82(448593.55) | valid_mse T=50 :6917.118 | valid_mse T=100 :7194.674
# Epoch:1995/2000 | tr_loss:323209.75(387177.54) | valid_mse T=50 :5305.257 | valid_mse T=100 :6430.703
# Epoch:1998/2000 | tr_loss:534982.07(427200.56) | valid_mse T=50 :8338.817 | valid_mse T=100 :8344.415
# Epoch:1995/2000 | tr_loss:401330.08(428213.09) | valid_mse T=50 :8327.987 | valid_mse T=100 :8655.629
# Epoch:1991/2000 | tr_loss:414870.34(447581.85) | valid_mse T=50 :6598.179 | valid_mse T=100 :7064.473
# Epoch:1996/2000 | tr_loss:439177.80(388737.55) | valid_mse T=50 :6464.033 | valid_mse T=100 :6677.310
# Epoch:1999/2000 | tr_loss:817846.53(438919.94) | valid_mse T=50 :7998.382 | valid_mse T=100 :9298.815
# Epoch:1999/2000 | time: 2:39:15.290920 | train_elbo: 817846.53 | train_mse: 884.615 | valid_mse_rec: 7998.382) | valid_mse_for: 9298.815)  | best_valid_mse: 4775.115)
# T=50 test_mse 353.603(0.000)
# T=100 test_mse 3537.194(0.000)
# Epoch:1996/2000 | tr_loss:341823.72(425621.41) | valid_mse T=50 :8252.192 | valid_mse T=100 :7930.347
# Epoch:1992/2000 | tr_loss:400182.27(446159.86) | valid_mse T=50 :5480.865 | valid_mse T=100 :6638.739
# Epoch:1997/2000 | tr_loss:369037.39(388146.55) | valid_mse T=50 :7346.364 | valid_mse T=100 :7288.563
# Epoch:1997/2000 | tr_loss:367144.70(423867.11) | valid_mse T=50 :8392.763 | valid_mse T=100 :8153.164
# Epoch:1993/2000 | tr_loss:319093.69(442347.88) | valid_mse T=50 :5827.955 | valid_mse T=100 :6579.485
# Epoch:1998/2000 | tr_loss:851098.54(402035.11) | valid_mse T=50 :6637.879 | valid_mse T=100 :6353.200
# Epoch:1998/2000 | tr_loss:534982.07(427200.56) | valid_mse T=50 :8338.817 | valid_mse T=100 :8344.415
# Epoch:1994/2000 | tr_loss:393560.07(440884.24) | valid_mse T=50 :5388.760 | valid_mse T=100 :6124.063
# Epoch:1999/2000 | tr_loss:620780.41(408597.47) | valid_mse T=50 :4708.028 | valid_mse T=100 :5329.173
# Epoch:1999/2000 | time: 2:39:21.627008 | train_elbo: 620780.41 | train_mse: 781.729 | valid_mse_rec: 4708.028) | valid_mse_for: 5329.173)  | best_valid_mse: 4280.413)
# T=50 test_mse 280.557(0.000)
# T=100 test_mse 1561.008(0.000)
# Epoch:1995/2000 | tr_loss:389355.27(439338.37) | valid_mse T=50 :6279.331 | valid_mse T=100 :6551.249
# Epoch:1999/2000 | tr_loss:817846.53(438919.94) | valid_mse T=50 :7998.382 | valid_mse T=100 :9298.815
# Epoch:1999/2000 | time: 2:39:22.359340 | train_elbo: 817846.53 | train_mse: 884.615 | valid_mse_rec: 7998.382) | valid_mse_for: 9298.815)  | best_valid_mse: 4775.115)
# T=50 test_mse 353.603(0.000)
# T=100 test_mse 3537.194(0.000)
# Epoch:1996/2000 | tr_loss:484598.27(440696.17) | valid_mse T=50 :6331.351 | valid_mse T=100 :6732.850
# Epoch:1997/2000 | tr_loss:400506.59(439490.48) | valid_mse T=50 :8745.462 | valid_mse T=100 :7620.770
# Epoch:1998/2000 | tr_loss:399086.61(438278.37) | valid_mse T=50 :7076.945 | valid_mse T=100 :7410.426
# Epoch:1999/2000 | tr_loss:449200.18(438606.02) | valid_mse T=50 :8348.970 | valid_mse T=100 :8068.057
# Epoch:1999/2000 | time: 2:39:27.861005 | train_elbo: 449200.18 | train_mse: 892.661 | valid_mse_rec: 8348.970) | valid_mse_for: 8068.057)  | best_valid_mse: 3983.976)
# T=50 test_mse 99.138(0.000)
# T=100 test_mse 2222.572(0.000)
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py", line 63, in __load_data
#     assert Xtr.shape[0] == params[dataset]['train']['N'] and Xtr.shape[1] == params[dataset]['train']['T']
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/yongmin/anaconda3/envs/NDE/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/yongmin/anaconda3/envs/NDE/lib/python3.12/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_1591865/1157229950.py", line 2, in match
#     buildArgs(setting[0], setting[1], setting[2], setting[3], setting[4], setting[5])
#   File "/tmp/ipykernel_1591865/609181076.py", line 66, in buildArgs
#     perform(args)
#   File "/tmp/ipykernel_1591865/3420771240.py", line 33, in perform
#     trainset, validset, testset, params = load_data(args, device, dtype)
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py", line 20, in load_data
#     (trainset, valset, testset), params = __load_data(args, device, dtype, args.task)
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py", line 90, in __load_data
#     Xvl = torch.load(data_path_vl)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yongmin/anaconda3/envs/NDE/lib/python3.12/site-packages/torch/serialization.py", line 1114, in load
#     return _legacy_load(
#            ^^^^^^^^^^^^^
#   File "/home/yongmin/anaconda3/envs/NDE/lib/python3.12/site-packages/torch/serialization.py", line 1338, in _legacy_load
#     magic_number = pickle_module.load(f, **pickle_load_args)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# EOFError: Ran out of input
# """
#
# The above exception was the direct cause of the following exception:
#
# EOFError                                  Traceback (most recent call last)
# Cell In[7], line 4
#       1 from multiprocessing import *
#       3 pool = Pool(processes=12)
# ----> 4 pool.map(func=match, iterable=settings)
#
# File ~/anaconda3/envs/NDE/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/anaconda3/envs/NDE/lib/python3.12/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# EOFError: Ran out of input

# %% [markdown]
# manually performed remain ones, setting[-3], setting[-5]

# %%
key = True
key2 = True
while key or key2:
    try:
        if key:
            match(settings[-3])
        key = False
    except:
        pass
    try:
        if key2:
            match(settings[-5])
        key2 = False
    except:
        pass
# Out:
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/30/
# Results stored in /media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/30/
# ********** Float type is torch.float64 **********
# ********** Float type is torch.float64 **********
# ********** Running model on cuda **********
# ********** Running model on cuda **********
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:89: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr = torch.load(data_path_tr)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:90: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xvl = torch.load(data_path_vl)
# /media/usr/SSD/yongmin/NDE/MONODE/data/data_utils.py:91: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte = torch.load(data_path_te)
# ********** ais dataset with loaded **********
# ********** ais dataset with loaded **********
# data params: {'train': {'N': 33, 'T': 50}, 'valid': {'N': 5, 'T': 50}, 'test': {'N': 8, 'T': 50}, 'dt': 0.05}
# data params: {'train': {'N': 33, 'T': 50}, 'valid': {'N': 5, 'T': 50}, 'test': {'N': 8, 'T': 50}, 'dt': 0.05}
# ********** Built node model with dynamics modulator dim 2 and  content variable dim 2**********
# ********** Built node model with dynamics modulator dim 2 and  content variable dim 2**********
# ********** Number of parameters: 37170 **********
# ********** Number of parameters: 37170 **********
# ********** Augmented Dynamics: True **********
# ********** Augmented Dynamics: True **********
# Argument Nepoch: 2000
# Argument Nepoch: 2000
# Argument Nincr: 3
# Argument Nincr: 3
# Argument Nobj: 1
# Argument Nobj: 1
# Argument T_in: 50
# Argument T_in: 50
# Argument T_inv: 50
# Argument T_inv: 50
# Argument batch_size: 16
# Argument batch_size: 16
# Argument cnn_filt_de: 16
# Argument cnn_filt_de: 16
# Argument cnn_filt_enc: 16
# Argument cnn_filt_enc: 16
# Argument cnn_filt_inv: 16
# Argument cnn_filt_inv: 16
# Argument content_dim: 2
# Argument content_dim: 2
# Argument continue_training: False
# Argument continue_training: False
# Argument data_root: 'AIS/'
# Argument data_root: 'AIS/'
# Argument de_H: 128
# Argument de_H: 128
# Argument de_L: 2
# Argument de_L: 2
# Argument dec_H: 128
# Argument dec_H: 128
# Argument dec_L: 2
# Argument dec_L: 2
# Argument dec_act: 'relu'
# Argument dec_act: 'relu'
# Argument dt: 0.1
# Argument dt: 0.1
# Argument enc_H: 50
# Argument enc_H: 50
# Argument exp_id: 30
# Argument exp_id: 30
# Argument forecast_tr: 2
# Argument forecast_tr: 2
# Argument forecast_vl: 2
# Argument forecast_vl: 2
# Argument inv_fnc: 'MLP'
# Argument inv_fnc: 'MLP'
# Argument lr: 0.002
# Argument lr: 0.002
# Argument model: 'node'
# Argument model: 'node'
# Argument modulator_dim: 2
# Argument modulator_dim: 2
# Argument noise: None
# Argument noise: None
# Argument num_workers: 0
# Argument num_workers: 0
# Argument ode_latent_dim: 2
# Argument ode_latent_dim: 2
# Argument order: 1
# Argument order: 1
# Argument plotL: 1
# Argument plotL: 1
# Argument plot_every: 250
# Argument plot_every: 250
# Argument rnn_hidden: 10
# Argument rnn_hidden: 10
# Argument save: '/media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/30/'
# Argument save: '/media/usr/SSD/yongmin/NDE/MONODE/results/ais/node/30/'
# Argument seed: 13
# Argument seed: 13
# Argument shuffle: True
# Argument shuffle: True
# Argument solver: 'euler'
# Argument solver: 'euler'
# Argument task: 'ais'
# Argument task: 'ais'
# Argument use_adjoint: 'no_adjoint'
# Argument use_adjoint: 'no_adjoint'
# MoNODE(
#   (flow): Flow(
#     (odefunc): ODEfunc(
#       (diffeq): MLP(
#         (layers): ModuleList(
#           (0): Linear(in_features=4, out_features=128, bias=True)
#           (1): Linear(in_features=128, out_features=128, bias=True)
#           (2): Linear(in_features=128, out_features=2, bias=True)
#         )
#         (acts): ModuleList(
#           (0-1): 2 x Softplus(beta=1.0, threshold=20.0)
#           (2): Identity()
#         )
#       )
#     )
#   )
#   (vae): VAE(
#     (encoder): EncoderRNN(
#       (sp): Softplus(beta=1.0, threshold=20.0)
#       (gru): GRUEncoder(
#         (rnn_hidden_to_latent): Sequential(
#           (0): Linear(in_features=10, out_features=50, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=50, out_features=4, bias=True)
#         )
#         (gru): GRU(2, 10)
#       )
#     )
#     (decoder): Decoder(
#       (net): MLP(
#         (layers): ModuleList(
#           (0): Linear(in_features=4, out_features=128, bias=True)
#           (1): Linear(in_features=128, out_features=128, bias=True)
#           (2): Linear(in_features=128, out_features=2, bias=True)
#         )
#         (acts): ModuleList(
#           (0-1): 2 x ReLU()
#           (2): Identity()
#         )
#       )
#       (sp): Softplus(beta=1.0, threshold=20.0)
#     )
#   )
#   (inv_enc): INV_ENC(
#     (inv_encoder): InvariantEncoderRNN(
#       (sp): Softplus(beta=1.0, threshold=20.0)
#       (gru): GRUEncoder(
#         (rnn_hidden_to_latent): Sequential(
#           (0): Linear(in_features=10, out_features=50, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=50, out_features=4, bias=True)
#         )
#         (gru): GRU(2, 10)
#       )
#     )
#   )
# )
# MoNODE(
#   (flow): Flow(
#     (odefunc): ODEfunc(
#       (diffeq): MLP(
#         (layers): ModuleList(
#           (0): Linear(in_features=4, out_features=128, bias=True)
#           (1): Linear(in_features=128, out_features=128, bias=True)
#           (2): Linear(in_features=128, out_features=2, bias=True)
#         )
#         (acts): ModuleList(
#           (0-1): 2 x Softplus(beta=1.0, threshold=20.0)
#           (2): Identity()
#         )
#       )
#     )
#   )
#   (vae): VAE(
#     (encoder): EncoderRNN(
#       (sp): Softplus(beta=1.0, threshold=20.0)
#       (gru): GRUEncoder(
#         (rnn_hidden_to_latent): Sequential(
#           (0): Linear(in_features=10, out_features=50, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=50, out_features=4, bias=True)
#         )
#         (gru): GRU(2, 10)
#       )
#     )
#     (decoder): Decoder(
#       (net): MLP(
#         (layers): ModuleList(
#           (0): Linear(in_features=4, out_features=128, bias=True)
#           (1): Linear(in_features=128, out_features=128, bias=True)
#           (2): Linear(in_features=128, out_features=2, bias=True)
#         )
#         (acts): ModuleList(
#           (0-1): 2 x ReLU()
#           (2): Identity()
#         )
#       )
#       (sp): Softplus(beta=1.0, threshold=20.0)
#     )
#   )
#   (inv_enc): INV_ENC(
#     (inv_encoder): InvariantEncoderRNN(
#       (sp): Softplus(beta=1.0, threshold=20.0)
#       (gru): GRUEncoder(
#         (rnn_hidden_to_latent): Sequential(
#           (0): Linear(in_features=10, out_features=50, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=50, out_features=4, bias=True)
#         )
#         (gru): GRU(2, 10)
#       )
#     )
#   )
# )
# ********** Started Training **********
# ********** Started Training **********
# ais
# True
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# ['ais', 'ais-vl-data.pkl', 'ais-tr-data.pkl', 'ais-te-data.pkl', 'data.pickle']
# Train data:  torch.Size([10, 100, 2])
# Val   data:  torch.Size([5, 100, 2])
# Test  data:  torch.Size([8, 100, 2])
# Epoch:   0/2000 | tr_loss:8971320.03(8971320.03) | valid_mse T=50 :10206.092 | valid_mse T=100 :9376.916
# Epoch:   0/2000 | tr_loss:8971320.03(8971320.03) | valid_mse T=50 :10206.092 | valid_mse T=100 :9376.916
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:   0/2000
# Epoch:   0/2000
# T=50 test_mse 8242.764(0.000)
# T=50 test_mse 8242.764(0.000)
# T=100 test_mse 8538.203(0.000)
# T=100 test_mse 8538.203(0.000)
# Epoch:   1/2000 | tr_loss:9186860.35(8977786.24) | valid_mse T=50 :10158.069 | valid_mse T=100 :9265.820
# Epoch:   1/2000 | tr_loss:9186860.35(8977786.24) | valid_mse T=50 :10158.069 | valid_mse T=100 :9265.820
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:   1/2000
# Epoch:   1/2000
# T=50 test_mse 8094.010(0.000)
# T=50 test_mse 8094.010(0.000)
# T=100 test_mse 8173.765(0.000)
# T=100 test_mse 8173.765(0.000)
# Epoch:   2/2000 | tr_loss:9205697.89(8984623.59) | valid_mse T=50 :10098.522 | valid_mse T=100 :9146.053
# Epoch:   2/2000 | tr_loss:9205697.89(8984623.59) | valid_mse T=50 :10098.522 | valid_mse T=100 :9146.053
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:   2/2000
# Epoch:   2/2000
# T=50 test_mse 7837.932(0.000)
# T=50 test_mse 7837.932(0.000)
# T=100 test_mse 7338.369(0.000)
# T=100 test_mse 7338.369(0.000)
# Epoch:   3/2000 | tr_loss:8659589.39(8974872.56) | valid_mse T=50 :9954.163 | valid_mse T=100 :9596.363
# Epoch:   3/2000 | tr_loss:8659589.39(8974872.56) | valid_mse T=50 :9954.163 | valid_mse T=100 :9596.363
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:   3/2000
# Epoch:   3/2000
# T=50 test_mse 7516.017(0.000)
# T=50 test_mse 7516.017(0.000)
# T=100 test_mse 6493.006(0.000)
# T=100 test_mse 6493.006(0.000)
# Epoch:   4/2000 | tr_loss:8802819.36(8969710.96) | valid_mse T=50 :9901.318 | valid_mse T=100 :19538.708
# Epoch:   4/2000 | tr_loss:8802819.36(8969710.96) | valid_mse T=50 :9901.318 | valid_mse T=100 :19538.708
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:   4/2000
# Epoch:   4/2000
# T=50 test_mse 6984.454(0.000)
# T=50 test_mse 6984.454(0.000)
# T=100 test_mse 12143.712(0.000)
# T=100 test_mse 12143.712(0.000)
# Epoch:   5/2000 | tr_loss:8894712.70(8967461.02) | valid_mse T=50 :9804.410 | valid_mse T=100 :170539.318
# Epoch:   5/2000 | tr_loss:8894712.70(8967461.02) | valid_mse T=50 :9804.410 | valid_mse T=100 :170539.318
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:   5/2000
# Epoch:   5/2000
# T=50 test_mse 6167.596(0.000)
# T=50 test_mse 6167.596(0.000)
# T=100 test_mse 124578.232(0.000)
# T=100 test_mse 124578.232(0.000)
# Epoch:   6/2000 | tr_loss:8836399.82(8963529.18) | valid_mse T=50 :10012.719 | valid_mse T=100 :1907188.718
# Epoch:   6/2000 | tr_loss:8836399.82(8963529.18) | valid_mse T=50 :10012.719 | valid_mse T=100 :1907188.718
# Epoch:   7/2000 | tr_loss:8469224.19(8948700.03) | valid_mse T=50 :14888.759 | valid_mse T=100 :37703803.915
# Epoch:   7/2000 | tr_loss:8469224.19(8948700.03) | valid_mse T=50 :14888.759 | valid_mse T=100 :37703803.915
# Epoch:   8/2000 | tr_loss:8226990.51(8927048.75) | valid_mse T=50 :41506.775 | valid_mse T=100 :704272911.401
# Epoch:   8/2000 | tr_loss:8226990.51(8927048.75) | valid_mse T=50 :41506.775 | valid_mse T=100 :704272911.401
# Epoch:   9/2000 | tr_loss:7695203.76(8890093.40) | valid_mse T=50 :200483.354 | valid_mse T=100 :16928691521.091
# Epoch:   9/2000 | tr_loss:7695203.76(8890093.40) | valid_mse T=50 :200483.354 | valid_mse T=100 :16928691521.091
# Epoch:  10/2000 | tr_loss:7671594.22(8853538.42) | valid_mse T=50 :1079664.505 | valid_mse T=100 :468444408852.795
# Epoch:  10/2000 | tr_loss:7671594.22(8853538.42) | valid_mse T=50 :1079664.505 | valid_mse T=100 :468444408852.795
# Epoch:  11/2000 | tr_loss:7076897.87(8800239.20) | valid_mse T=50 :5868752.152 | valid_mse T=100 :14168350733480.416
# Epoch:  11/2000 | tr_loss:7076897.87(8800239.20) | valid_mse T=50 :5868752.152 | valid_mse T=100 :14168350733480.416
# Epoch:  12/2000 | tr_loss:6785747.67(8739804.46) | valid_mse T=50 :53230228.786 | valid_mse T=100 :832870852864797.500
# Epoch:  12/2000 | tr_loss:6785747.67(8739804.46) | valid_mse T=50 :53230228.786 | valid_mse T=100 :832870852864797.500
# Epoch:  60/2000 | tr_loss:2116956.60(4976107.63) | valid_mse T=50 :10743.243 | valid_mse T=100 :27047.811
# Epoch:  61/2000 | tr_loss:2612974.78(4905213.64) | valid_mse T=50 :9980.155 | valid_mse T=100 :21171.457
# Epoch:  61/2000 | tr_loss:2612974.78(4905213.64) | valid_mse T=50 :9980.155 | valid_mse T=100 :21171.457
# Epoch:  62/2000 | tr_loss:2095571.93(4820924.39) | valid_mse T=50 :9437.764 | valid_mse T=100 :17478.909
# Epoch:  62/2000 | tr_loss:2095571.93(4820924.39) | valid_mse T=50 :9437.764 | valid_mse T=100 :17478.909
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  62/2000
# Epoch:  62/2000
# T=50 test_mse 1555.621(0.000)
# T=50 test_mse 1555.621(0.000)
# T=100 test_mse 16579.623(0.000)
# T=100 test_mse 16579.623(0.000)
# Epoch:  63/2000 | tr_loss:1962611.35(4735175.00) | valid_mse T=50 :9689.112 | valid_mse T=100 :16234.696
# Epoch:  63/2000 | tr_loss:1962611.35(4735175.00) | valid_mse T=50 :9689.112 | valid_mse T=100 :16234.696
# Epoch:  64/2000 | tr_loss:1580314.02(4640529.17) | valid_mse T=50 :9076.064 | valid_mse T=100 :14011.855
# Epoch:  64/2000 | tr_loss:1580314.02(4640529.17) | valid_mse T=50 :9076.064 | valid_mse T=100 :14011.855
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  64/2000
# Epoch:  64/2000
# T=50 test_mse 1121.216(0.000)
# T=50 test_mse 1121.216(0.000)
# T=100 test_mse 10471.302(0.000)
# T=100 test_mse 10471.302(0.000)
# Epoch:  65/2000 | tr_loss:1996597.88(4561211.23) | valid_mse T=50 :8856.190 | valid_mse T=100 :12206.079
# Epoch:  65/2000 | tr_loss:1996597.88(4561211.23) | valid_mse T=50 :8856.190 | valid_mse T=100 :12206.079
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  65/2000
# Epoch:  65/2000
# T=50 test_mse 928.726(0.000)
# T=50 test_mse 928.726(0.000)
# T=100 test_mse 8663.910(0.000)
# T=100 test_mse 8663.910(0.000)
# Epoch:  66/2000 | tr_loss:2039066.95(4485546.91) | valid_mse T=50 :9018.132 | valid_mse T=100 :11994.983
# Epoch:  66/2000 | tr_loss:2039066.95(4485546.91) | valid_mse T=50 :9018.132 | valid_mse T=100 :11994.983
# Epoch:  67/2000 | tr_loss:1902672.61(4408060.68) | valid_mse T=50 :7947.146 | valid_mse T=100 :9869.373
# Epoch:  67/2000 | tr_loss:1902672.61(4408060.68) | valid_mse T=50 :7947.146 | valid_mse T=100 :9869.373
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  67/2000
# Epoch:  67/2000
# T=50 test_mse 672.846(0.000)
# T=50 test_mse 672.846(0.000)
# T=100 test_mse 6191.703(0.000)
# T=100 test_mse 6191.703(0.000)
# Epoch:  68/2000 | tr_loss:2032443.74(4336792.17) | valid_mse T=50 :8219.184 | valid_mse T=100 :10449.854
# Epoch:  68/2000 | tr_loss:2032443.74(4336792.17) | valid_mse T=50 :8219.184 | valid_mse T=100 :10449.854
# Epoch:  69/2000 | tr_loss:2303175.02(4275783.65) | valid_mse T=50 :9013.702 | valid_mse T=100 :9484.531
# Epoch:  69/2000 | tr_loss:2303175.02(4275783.65) | valid_mse T=50 :9013.702 | valid_mse T=100 :9484.531
# Epoch:  70/2000 | tr_loss:1985540.57(4207076.36) | valid_mse T=50 :8392.302 | valid_mse T=100 :9068.068
# Epoch:  70/2000 | tr_loss:1985540.57(4207076.36) | valid_mse T=50 :8392.302 | valid_mse T=100 :9068.068
# Epoch:  71/2000 | tr_loss:1676318.02(4131153.61) | valid_mse T=50 :7897.983 | valid_mse T=100 :9186.455
# Epoch:  71/2000 | tr_loss:1676318.02(4131153.61) | valid_mse T=50 :7897.983 | valid_mse T=100 :9186.455
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  71/2000
# Epoch:  71/2000
# T=50 test_mse 577.272(0.000)
# T=50 test_mse 577.272(0.000)
# T=100 test_mse 4078.990(0.000)
# T=100 test_mse 4078.990(0.000)
# Epoch:  72/2000 | tr_loss:1171673.22(4042369.20) | valid_mse T=50 :7974.510 | valid_mse T=100 :9179.967
# Epoch:  72/2000 | tr_loss:1171673.22(4042369.20) | valid_mse T=50 :7974.510 | valid_mse T=100 :9179.967
# Epoch:  73/2000 | tr_loss:1499472.06(3966082.28) | valid_mse T=50 :8033.421 | valid_mse T=100 :8686.818
# Epoch:  73/2000 | tr_loss:1499472.06(3966082.28) | valid_mse T=50 :8033.421 | valid_mse T=100 :8686.818
# Epoch:  74/2000 | tr_loss:1762187.31(3899965.44) | valid_mse T=50 :7973.060 | valid_mse T=100 :8338.551
# Epoch:  74/2000 | tr_loss:1762187.31(3899965.44) | valid_mse T=50 :7973.060 | valid_mse T=100 :8338.551
# Epoch:  75/2000 | tr_loss:1308946.46(3822234.87) | valid_mse T=50 :7650.378 | valid_mse T=100 :8007.946
# Epoch:  75/2000 | tr_loss:1308946.46(3822234.87) | valid_mse T=50 :7650.378 | valid_mse T=100 :8007.946
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  75/2000
# Epoch:  75/2000
# T=50 test_mse 382.034(0.000)
# T=50 test_mse 382.034(0.000)
# T=100 test_mse 3259.209(0.000)
# T=100 test_mse 3259.209(0.000)
# Epoch:  76/2000 | tr_loss:2139276.18(3771746.11) | valid_mse T=50 :7388.787 | valid_mse T=100 :7902.088
# Epoch:  76/2000 | tr_loss:2139276.18(3771746.11) | valid_mse T=50 :7388.787 | valid_mse T=100 :7902.088
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  76/2000
# Epoch:  76/2000
# T=50 test_mse 423.378(0.000)
# T=50 test_mse 423.378(0.000)
# T=100 test_mse 2908.696(0.000)
# T=100 test_mse 2908.696(0.000)
# Epoch:  77/2000 | tr_loss:1643427.25(3707896.54) | valid_mse T=50 :7627.462 | valid_mse T=100 :8235.184
# Epoch:  77/2000 | tr_loss:1643427.25(3707896.54) | valid_mse T=50 :7627.462 | valid_mse T=100 :8235.184
# Epoch:  78/2000 | tr_loss:2043512.43(3657965.02) | valid_mse T=50 :8065.220 | valid_mse T=100 :7845.556
# Epoch:  78/2000 | tr_loss:2043512.43(3657965.02) | valid_mse T=50 :8065.220 | valid_mse T=100 :7845.556
# Epoch:  79/2000 | tr_loss:1895375.98(3605087.35) | valid_mse T=50 :7112.660 | valid_mse T=100 :7707.185
# Epoch:  79/2000 | tr_loss:1895375.98(3605087.35) | valid_mse T=50 :7112.660 | valid_mse T=100 :7707.185
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  79/2000
# Epoch:  79/2000
# T=50 test_mse 510.148(0.000)
# T=50 test_mse 510.148(0.000)
# T=100 test_mse 2664.400(0.000)
# T=100 test_mse 2664.400(0.000)
# Epoch:  80/2000 | tr_loss:1661312.97(3546774.11) | valid_mse T=50 :8727.397 | valid_mse T=100 :8468.037
# Epoch:  80/2000 | tr_loss:1661312.97(3546774.11) | valid_mse T=50 :8727.397 | valid_mse T=100 :8468.037
# Epoch:  81/2000 | tr_loss:1482197.36(3484836.81) | valid_mse T=50 :7091.636 | valid_mse T=100 :7688.251
# Epoch:  81/2000 | tr_loss:1482197.36(3484836.81) | valid_mse T=50 :7091.636 | valid_mse T=100 :7688.251
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  81/2000
# Epoch:  81/2000
# T=50 test_mse 355.442(0.000)
# T=50 test_mse 355.442(0.000)
# T=100 test_mse 2871.457(0.000)
# T=100 test_mse 2871.457(0.000)
# Epoch:  82/2000 | tr_loss:1817300.86(3434810.73) | valid_mse T=50 :7179.119 | valid_mse T=100 :7722.467
# Epoch:  82/2000 | tr_loss:1817300.86(3434810.73) | valid_mse T=50 :7179.119 | valid_mse T=100 :7722.467
# Epoch:  83/2000 | tr_loss:1983173.04(3391261.60) | valid_mse T=50 :7379.034 | valid_mse T=100 :8107.553
# Epoch:  83/2000 | tr_loss:1983173.04(3391261.60) | valid_mse T=50 :7379.034 | valid_mse T=100 :8107.553
# Epoch:  84/2000 | tr_loss:1519161.06(3335098.59) | valid_mse T=50 :7391.939 | valid_mse T=100 :7352.865
# Epoch:  84/2000 | tr_loss:1519161.06(3335098.59) | valid_mse T=50 :7391.939 | valid_mse T=100 :7352.865
# Epoch:  85/2000 | tr_loss:1271925.23(3273203.39) | valid_mse T=50 :7165.077 | valid_mse T=100 :7583.573
# Epoch:  85/2000 | tr_loss:1271925.23(3273203.39) | valid_mse T=50 :7165.077 | valid_mse T=100 :7583.573
# Epoch:  86/2000 | tr_loss:1638779.61(3224170.67) | valid_mse T=50 :8056.211 | valid_mse T=100 :7610.032
# Epoch:  86/2000 | tr_loss:1638779.61(3224170.67) | valid_mse T=50 :8056.211 | valid_mse T=100 :7610.032
# Epoch:  87/2000 | tr_loss:1959658.85(3186235.32) | valid_mse T=50 :6819.816 | valid_mse T=100 :7255.628
# Epoch:  87/2000 | tr_loss:1959658.85(3186235.32) | valid_mse T=50 :6819.816 | valid_mse T=100 :7255.628
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  87/2000
# Epoch:  87/2000
# T=50 test_mse 491.106(0.000)
# T=50 test_mse 491.106(0.000)
# T=100 test_mse 2400.213(0.000)
# T=100 test_mse 2400.213(0.000)
# Epoch:  88/2000 | tr_loss:1172850.37(3125833.77) | valid_mse T=50 :7899.553 | valid_mse T=100 :7243.790
# Epoch:  88/2000 | tr_loss:1172850.37(3125833.77) | valid_mse T=50 :7899.553 | valid_mse T=100 :7243.790
# Epoch:  89/2000 | tr_loss:1742636.26(3084337.84) | valid_mse T=50 :7358.229 | valid_mse T=100 :7322.097
# Epoch:  89/2000 | tr_loss:1742636.26(3084337.84) | valid_mse T=50 :7358.229 | valid_mse T=100 :7322.097
# Epoch:  90/2000 | tr_loss:1611090.99(3040140.44) | valid_mse T=50 :6917.221 | valid_mse T=100 :6941.564
# Epoch:  90/2000 | tr_loss:1611090.99(3040140.44) | valid_mse T=50 :6917.221 | valid_mse T=100 :6941.564
# Epoch:  91/2000 | tr_loss:1871533.11(3005082.22) | valid_mse T=50 :6764.983 | valid_mse T=100 :6935.249
# Epoch:  91/2000 | tr_loss:1871533.11(3005082.22) | valid_mse T=50 :6764.983 | valid_mse T=100 :6935.249
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  91/2000
# Epoch:  91/2000
# T=50 test_mse 329.736(0.000)
# T=50 test_mse 329.736(0.000)
# T=100 test_mse 2403.137(0.000)
# T=100 test_mse 2403.137(0.000)
# Epoch:  92/2000 | tr_loss:1931120.21(2972863.36) | valid_mse T=50 :6560.135 | valid_mse T=100 :7276.446
# Epoch:  92/2000 | tr_loss:1931120.21(2972863.36) | valid_mse T=50 :6560.135 | valid_mse T=100 :7276.446
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  92/2000
# Epoch:  92/2000
# T=50 test_mse 324.174(0.000)
# T=50 test_mse 324.174(0.000)
# T=100 test_mse 2366.394(0.000)
# T=100 test_mse 2366.394(0.000)
# Epoch:  93/2000 | tr_loss:1549262.28(2930155.33) | valid_mse T=50 :6583.366 | valid_mse T=100 :6798.371
# Epoch:  93/2000 | tr_loss:1549262.28(2930155.33) | valid_mse T=50 :6583.366 | valid_mse T=100 :6798.371
# Epoch:  94/2000 | tr_loss:1515610.39(2887718.98) | valid_mse T=50 :6497.042 | valid_mse T=100 :6652.146
# Epoch:  94/2000 | tr_loss:1515610.39(2887718.98) | valid_mse T=50 :6497.042 | valid_mse T=100 :6652.146
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  94/2000
# Epoch:  94/2000
# T=50 test_mse 357.841(0.000)
# T=50 test_mse 357.841(0.000)
# T=100 test_mse 2428.992(0.000)
# T=100 test_mse 2428.992(0.000)
# Epoch:  95/2000 | tr_loss:1427769.48(2843920.49) | valid_mse T=50 :6384.538 | valid_mse T=100 :6615.747
# Epoch:  95/2000 | tr_loss:1427769.48(2843920.49) | valid_mse T=50 :6384.538 | valid_mse T=100 :6615.747
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:  95/2000
# Epoch:  95/2000
# T=50 test_mse 653.405(0.000)
# T=50 test_mse 653.405(0.000)
# T=100 test_mse 2031.532(0.000)
# T=100 test_mse 2031.532(0.000)
# Epoch:  96/2000 | tr_loss:1167920.22(2793640.49) | valid_mse T=50 :6416.892 | valid_mse T=100 :6466.688
# Epoch:  96/2000 | tr_loss:1167920.22(2793640.49) | valid_mse T=50 :6416.892 | valid_mse T=100 :6466.688
# Epoch:  97/2000 | tr_loss:1377214.75(2751147.71) | valid_mse T=50 :6182.246 | valid_mse T=100 :6336.966
# Epoch:  97/2000 | tr_loss:1377214.75(2751147.71) | valid_mse T=50 :6182.246 | valid_mse T=100 :6336.966
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch:
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch: 119/2000
# Epoch: 119/2000
# T=50 test_mse 227.584(0.000)
# T=50 test_mse 227.584(0.000)
# T=100 test_mse 2276.797(0.000)
# T=100 test_mse 2276.797(0.000)
# Epoch: 120/2000 | tr_loss:644251.47(1943792.34) | valid_mse T=50 :5098.090 | valid_mse T=100 :10286.641
# Epoch: 120/2000 | tr_loss:644251.47(1943792.34) | valid_mse T=50 :5098.090 | valid_mse T=100 :10286.641
# ********** Current Best Model based on validation error ***********
# ********** Current Best Model based on validation error ***********
# Epoch: 120/2000
# Epoch: 120/2000
# T=50 test_mse 240.769(0.000)
# T=50 test_mse 240.769(0.000)
# T=100 test_mse 2264.282(0.000)
# T=100 test_mse 2264.282(0.000)
# Epoch: 121/2000 | tr_loss:1184993.52(1921028.38) | valid_mse T=50 :5305.072 | valid_mse T=100 :9800.141
# Epoch: 121/2000 | tr_loss:1184993.52(1921028.38) | valid_mse T=50 :5305.072 | valid_mse T=100 :9800.141
# Epoch: 122/2000 | tr_loss:553692.50(1880008.30) | valid_mse T=50 :5107.955 | valid_mse T=100 :9622.292
# Epoch: 122/2000 | tr_loss:553692.50(1880008.30) | valid_mse T=50 :5107.955 | valid_mse T=100 :9622.292
# Epoch: 123/2000 | tr_loss:598318.18(1841557.60) | valid_mse T=50 :6779.115 | valid_mse T=100 :6288.285
# Epoch: 123/2000 | tr_loss:598318.18(1841557.60) | valid_mse T=50 :6779.115 | valid_mse T=100 :6288.285
# Epoch: 124/2000 | tr_loss:1666972.24(1836320.04) | valid_mse T=50 :5181.596 | valid_mse T=100 :9053.994
# Epoch: 124/2000 | tr_loss:1666972.24(1836320.04) | valid_mse T=50 :5181.596 | valid_mse T=100 :9053.994
# Epoch: 125/2000 | tr_loss:1103087.12(1814323.05) | valid_mse T=50 :5332.011 | valid_mse T=100 :7436.156
# Epoch: 125/2000 | tr_loss:1103087.12(1814323.05) | valid_mse T=50 :5332.011 | valid_mse T=100 :7436.156
# Epoch: 126/2000 | tr_loss:845643.29(1785262.66) | valid_mse T=50 :6535.904 | valid_mse T=100 :6699.943
# Epoch: 126/2000 | tr_loss:845643.29(1785262.66) | valid_mse T=50 :6535.904 | valid_mse T=100 :6699.943
# Epoch: 127/2000 | tr_loss:1164301.33(1766633.82) | valid_mse T=50 :5500.551 | valid_mse T=100 :7872.607
# Epoch: 127/2000 | tr_loss:1164301.33(1766633.82) | valid_mse T=50 :5500.551 | valid_mse T=100 :7872.607
# Epoch: 128/2000 | tr_loss:748735.82(1736096.88) | valid_mse T=50 :5659.095 | valid_mse T=100 :5929.272
# Epoch: 128/2000 | tr_loss:748735.82(1736096.88) | valid_mse T=50 :5659.095 | valid_mse T=100 :5929.272
# Epoch: 129/2000 | tr_loss:971229.41(1713150.85) | valid_mse T=50 :5594.687 | valid_mse T=100 :6381.022
# ...
# Epoch:1950/2000 | tr_loss:477660.36(419349.19) | valid_mse T=50 :8531.866 | valid_mse T=100 :7958.029
# Epoch:1951/2000 | tr_loss:323965.24(416487.67) | valid_mse T=50 :8191.222 | valid_mse T=100 :7104.061
# Epoch:1951/2000 | tr_loss:323965.24(416487.67) | valid_mse T=50 :8191.222 | valid_mse T=100 :7104.061
# Epoch:1951/2000 | tr_loss:323965.24(416487.67) | valid_mse T=50 :8191.222 | valid_mse T=100 :7104.061
# Epoch:1952/2000 | tr_loss:296300.25(412882.05) | valid_mse T=50 :8472.262 | valid_mse T=100 :7422.333
# Epoch:1952/2000 | tr_loss:296300.25(412882.05) | valid_mse T=50 :8472.262 | valid_mse T=100 :7422.333
# Epoch:1952/2000 | tr_loss:296300.25(412882.05) | valid_mse T=50 :8472.262 | valid_mse T=100 :7422.333
# Epoch:1953/2000 | tr_loss:416664.87(412995.53) | valid_mse T=50 :8816.723 | valid_mse T=100 :8543.067
# Epoch:1953/2000 | tr_loss:416664.87(412995.53) | valid_mse T=50 :8816.723 | valid_mse T=100 :8543.067
# Epoch:1953/2000 | tr_loss:416664.87(412995.53) | valid_mse T=50 :8816.723 | valid_mse T=100 :8543.067
# Epoch:1954/2000 | tr_loss:491288.85(415344.33) | valid_mse T=50 :8801.524 | valid_mse T=100 :8405.819
# Epoch:1954/2000 | tr_loss:491288.85(415344.33) | valid_mse T=50 :8801.524 | valid_mse T=100 :8405.819
# Epoch:1954/2000 | tr_loss:491288.85(415344.33) | valid_mse T=50 :8801.524 | valid_mse T=100 :8405.819
# Epoch:1955/2000 | tr_loss:320880.83(412510.43) | valid_mse T=50 :8367.730 | valid_mse T=100 :7495.532
# Epoch:1955/2000 | tr_loss:320880.83(412510.43) | valid_mse T=50 :8367.730 | valid_mse T=100 :7495.532
# Epoch:1955/2000 | tr_loss:320880.83(412510.43) | valid_mse T=50 :8367.730 | valid_mse T=100 :7495.532
# Epoch:1956/2000 | tr_loss:432146.40(413099.51) | valid_mse T=50 :8297.755 | valid_mse T=100 :7448.079
# Epoch:1956/2000 | tr_loss:432146.40(413099.51) | valid_mse T=50 :8297.755 | valid_mse T=100 :7448.079
# Epoch:1956/2000 | tr_loss:432146.40(413099.51) | valid_mse T=50 :8297.755 | valid_mse T=100 :7448.079
# Epoch:1957/2000 | tr_loss:407756.04(412939.20) | valid_mse T=50 :8930.173 | valid_mse T=100 :7274.030
# Epoch:1957/2000 | tr_loss:407756.04(412939.20) | valid_mse T=50 :8930.173 | valid_mse T=100 :7274.030
# Epoch:1957/2000 | tr_loss:407756.04(412939.20) | valid_mse T=50 :8930.173 | valid_mse T=100 :7274.030
# Epoch:1958/2000 | tr_loss:447103.12(413964.12) | valid_mse T=50 :8761.431 | valid_mse T=100 :7271.395
# Epoch:1958/2000 | tr_loss:447103.12(413964.12) | valid_mse T=50 :8761.431 | valid_mse T=100 :7271.395
# Epoch:1958/2000 | tr_loss:447103.12(413964.12) | valid_mse T=50 :8761.431 | valid_mse T=100 :7271.395
# Epoch:1959/2000 | tr_loss:373027.25(412736.01) | valid_mse T=50 :8393.433 | valid_mse T=100 :7955.523
# Epoch:1959/2000 | tr_loss:373027.25(412736.01) | valid_mse T=50 :8393.433 | valid_mse T=100 :7955.523
# Epoch:1959/2000 | tr_loss:373027.25(412736.01) | valid_mse T=50 :8393.433 | valid_mse T=100 :7955.523
# Epoch:1960/2000 | tr_loss:456909.38(414061.22) | valid_mse T=50 :7880.124 | valid_mse T=100 :8756.796
# Epoch:1960/2000 | tr_loss:456909.38(414061.22) | valid_mse T=50 :7880.124 | valid_mse T=100 :8756.796
# Epoch:1960/2000 | tr_loss:456909.38(414061.22) | valid_mse T=50 :7880.124 | valid_mse T=100 :8756.796
# Epoch:1961/2000 | tr_loss:410314.76(413948.82) | valid_mse T=50 :7690.986 | valid_mse T=100 :9234.576
# Epoch:1961/2000 | tr_loss:410314.76(413948.82) | valid_mse T=50 :7690.986 | valid_mse T=100 :9234.576
# Epoch:1961/2000 | tr_loss:410314.76(413948.82) | valid_mse T=50 :7690.986 | valid_mse T=100 :9234.576
# Epoch:1962/2000 | tr_loss:424147.91(414254.79) | valid_mse T=50 :7908.816 | valid_mse T=100 :9499.690
# Epoch:1962/2000 | tr_loss:424147.91(414254.79) | valid_mse T=50 :7908.816 | valid_mse T=100 :9499.690
# Epoch:1962/2000 | tr_loss:424147.91(414254.79) | valid_mse T=50 :7908.816 | valid_mse T=100 :9499.690
# Epoch:1963/2000 | tr_loss:444909.83(415174.44) | valid_mse T=50 :8468.719 | valid_mse T=100 :9854.975
# Epoch:1963/2000 | tr_loss:444909.83(415174.44) | valid_mse T=50 :8468.719 | valid_mse T=100 :9854.975
# Epoch:1963/2000 | tr_loss:444909.83(415174.44) | valid_mse T=50 :8468.719 | valid_mse T=100 :9854.975
# Epoch:1964/2000 | tr_loss:411906.11(415076.39) | valid_mse T=50 :9135.094 | valid_mse T=100 :8690.202
# Epoch:1964/2000 | tr_loss:411906.11(415076.39) | valid_mse T=50 :9135.094 | valid_mse T=100 :8690.202
# Epoch:1964/2000 | tr_loss:411906.11(415076.39) | valid_mse T=50 :9135.094 | valid_mse T=100 :8690.202
# Epoch:1965/2000 | tr_loss:313947.49(412042.53) | valid_mse T=50 :9068.045 | valid_mse T=100 :7700.801
# Epoch:1965/2000 | tr_loss:313947.49(412042.53) | valid_mse T=50 :9068.045 | valid_mse T=100 :7700.801
# Epoch:1965/2000 | tr_loss:313947.49(412042.53) | valid_mse T=50 :9068.045 | valid_mse T=100 :7700.801
# Epoch:1966/2000 | tr_loss:516715.40(415182.71) | valid_mse T=50 :8676.469 | valid_mse T=100 :8315.142
# Epoch:1966/2000 | tr_loss:516715.40(415182.71) | valid_mse T=50 :8676.469 | valid_mse T=100 :8315.142
# Epoch:1966/2000 | tr_loss:516715.40(415182.71) | valid_mse T=50 :8676.469 | valid_mse T=100 :8315.142
# Epoch:1967/2000 | tr_loss:580227.06(420134.04) | valid_mse T=50 :6763.792 | valid_mse T=100 :5994.826
# Epoch:1967/2000 | tr_loss:580227.06(420134.04) | valid_mse T=50 :6763.792 | valid_mse T=100 :5994.826
# Epoch:1967/2000 | tr_loss:580227.06(420134.04) | valid_mse T=50 :6763.792 | valid_mse T=100 :5994.826
# Epoch:1968/2000 | tr_loss:476221.94(421816.68) | valid_mse T=50 :8361.508 | valid_mse T=100 :9857.172
# Epoch:1968/2000 | tr_loss:476221.94(421816.68) | valid_mse T=50 :8361.508 | valid_mse T=100 :9857.172
# Epoch:1994/2000 | tr_loss:431010.68(429044.52) | valid_mse T=50 :8638.049 | valid_mse T=100 :8459.916
# Epoch:1994/2000 | tr_loss:431010.68(429044.52) | valid_mse T=50 :8638.049 | valid_mse T=100 :8459.916
# Epoch:1994/2000 | tr_loss:431010.68(429044.52) | valid_mse T=50 :8638.049 | valid_mse T=100 :8459.916
# Epoch:1995/2000 | tr_loss:401330.08(428213.09) | valid_mse T=50 :8327.987 | valid_mse T=100 :8655.629
# Epoch:1995/2000 | tr_loss:401330.08(428213.09) | valid_mse T=50 :8327.987 | valid_mse T=100 :8655.629
# Epoch:1995/2000 | tr_loss:401330.08(428213.09) | valid_mse T=50 :8327.987 | valid_mse T=100 :8655.629
# Epoch:1996/2000 | tr_loss:341823.72(425621.41) | valid_mse T=50 :8252.192 | valid_mse T=100 :7930.347
# Epoch:1996/2000 | tr_loss:341823.72(425621.41) | valid_mse T=50 :8252.192 | valid_mse T=100 :7930.347
# Epoch:1996/2000 | tr_loss:341823.72(425621.41) | valid_mse T=50 :8252.192 | valid_mse T=100 :7930.347
# Epoch:1997/2000 | tr_loss:367144.70(423867.11) | valid_mse T=50 :8392.763 | valid_mse T=100 :8153.164
# Epoch:1997/2000 | tr_loss:367144.70(423867.11) | valid_mse T=50 :8392.763 | valid_mse T=100 :8153.164
# Epoch:1997/2000 | tr_loss:367144.70(423867.11) | valid_mse T=50 :8392.763 | valid_mse T=100 :8153.164
# Epoch:1998/2000 | tr_loss:534982.07(427200.56) | valid_mse T=50 :8338.817 | valid_mse T=100 :8344.415
# Epoch:1998/2000 | tr_loss:534982.07(427200.56) | valid_mse T=50 :8338.817 | valid_mse T=100 :8344.415
# Epoch:1998/2000 | tr_loss:534982.07(427200.56) | valid_mse T=50 :8338.817 | valid_mse T=100 :8344.415
# Epoch:1999/2000 | tr_loss:817846.53(438919.94) | valid_mse T=50 :7998.382 | valid_mse T=100 :9298.815
# Epoch:1999/2000 | tr_loss:817846.53(438919.94) | valid_mse T=50 :7998.382 | valid_mse T=100 :9298.815
# Epoch:1999/2000 | tr_loss:817846.53(438919.94) | valid_mse T=50 :7998.382 | valid_mse T=100 :9298.815
# Epoch:1999/2000 | time: 0:26:18.012444 | train_elbo: 817846.53 | train_mse: 884.615 | valid_mse_rec: 7998.382) | valid_mse_for: 9298.815)  | best_valid_mse: 4775.115)
# Epoch:1999/2000 | time: 0:26:18.012444 | train_elbo: 817846.53 | train_mse: 884.615 | valid_mse_rec: 7998.382) | valid_mse_for: 9298.815)  | best_valid_mse: 4775.115)
# Epoch:1999/2000 | time: 0:26:18.012444 | train_elbo: 817846.53 | train_mse: 884.615 | valid_mse_rec: 7998.382) | valid_mse_for: 9298.815)  | best_valid_mse: 4775.115)
# T=50 test_mse 353.603(0.000)
# T=50 test_mse 353.603(0.000)
# T=50 test_mse 353.603(0.000)
# T=100 test_mse 3537.194(0.000)
# T=100 test_mse 3537.194(0.000)
# T=100 test_mse 3537.194(0.000)

# %% [markdown]
# Check the results by access the log files in the result folder.
